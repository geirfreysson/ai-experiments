# %% [raw]
# ---
# title: Reliable Data Driven AI Agents
# abstract: I'm giving a talk at PyData London November's meetup on Reliable Data Driven AI Agents. The talk is titled Using Hugging Face's smolagents framework to create a Fantasy Premier League AI Agent.
# date: "2025-11-03"
# draft: false
# publish: true
# image: talk-front-page.png
# callout-appearance: simple
# categories: [pydata, smolagents, fpl, ai-agents]
# ---

# %% [markdown]
# ![](talk-front-page.png)

# %% [markdown]
# ## PyData London November 2025
# I have the great honour to be speaking at [PyData London November 2025](https://www.meetup.com/pydata-london-meetup/events/311635959/) on November 4th, 2025.
#
# My talk is titled "**Reliable Data Driven AI Agents: Using Hugging Face's smolagents framework to create a Fantasy Premier League AI Agent.**"
#
# This is a great event and there's always a waiting list to get in, so I look forward to meeting other Python folks.
#
# Slides will be uploaded here after the talk.
